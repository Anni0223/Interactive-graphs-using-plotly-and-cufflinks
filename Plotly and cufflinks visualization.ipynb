# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__)
# Out:
# 5.6.0

# %%
import cufflinks as cf

# %%
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
# ...

# %%
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})
df.head()
# Out:
#           A         B         C         D
# 0 -0.199831 -0.711519 -0.077449 -0.172690
# 1  0.436967 -0.287453 -0.183841 -1.007394
# 2 -0.972572 -0.781233  1.947741 -0.432215
# 3 -0.255775 -0.121423  1.074938 -1.120530
# 4 -1.618486 -2.265471  1.628955  0.665888

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=10)
# Out:
# <div>                            <div id="7364c4e6-92a8-4a4c-98c2-5166089d729f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>                            <div id="0310a278-0a7f-4416-986c-5c20c6c1dc08" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#            A         B         C         D
# 0  -0.199831 -0.711519 -0.077449 -0.172690
# 1   0.436967 -0.287453 -0.183841 -1.007394
# 2  -0.972572 -0.781233  1.947741 -0.432215
# 3  -0.255775 -0.121423  1.074938 -1.120530
# 4  -1.618486 -2.265471  1.628955  0.665888
# ..       ...       ...       ...       ...
# 95  0.174319 -1.223491 -0.038038  0.701263
# 96  0.863007 -0.124545  1.919786 -0.627882
# 97  1.091225  0.380442 -1.230083 -0.301574
# 98  0.077678 -0.398550 -0.324194 -1.178101
# 99  1.750498  0.389564 -1.213384 -1.195356
#
# [100 rows x 4 columns]

# %%
df.iplot(kind='bar')
# Out:
# <div>                            <div id="ca1fc2f7-ce31-45bd-b840-cabf24a08f26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## We can even use agrregate functions.. HOW COOL IS THAT

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>                            <div id="0e818978-d2ba-47cb-85fc-34e1d2a9929e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='box')  #CAn click on legends to show a particular one
# Out:
# <div>                            <div id="cf2d5b2a-b5fd-4824-9594-2ddf7385c2d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3=pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[500,400,300,200,100]})
df3
# Out:
#    x   y    z
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  20  200
# 4  5  10  100

# %%
df3.iplot(kind='surface')
# Out:
# <div>                            <div id="19154aec-43e9-4d73-b044-1e696fe9ba3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>                            <div id="5f25cac9-1b97-488c-95a5-a72afaef0347" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df['A'].iplot(kind='hist',bins=40)
# Out:
# <div>                            <div id="12b657d8-7ccb-4cee-87bd-e5a68f2df524" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='hist',bins=40)
# Out:
# <div>                            <div id="344090be-ad36-447a-b1da-51b991537892" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# C:\Users\91938\anaconda3\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# C:\Users\91938\anaconda3\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>                            <div id="360343c5-90bd-4cfa-88ed-ab0eee8350d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>                            <div id="5960f0eb-60ad-4caf-913e-3cb8de20c214" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="4e5ed8fe-7edf-43a2-96b8-c664d183dfbe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## Check out cufflinks github it also has technical analysis abilities.
